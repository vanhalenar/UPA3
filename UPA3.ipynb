# %%
import pandas as pd
import seaborn as sns
import re

# %%
names = ['url', 'book name', 'price', 'category', 'language', 'author', 'publisher', 'isbn', 'binding', 'date published', 'num. pages', 'dimensions', 'weight', 'status', 'discount']
df = pd.read_csv('data.tsv', sep="\t", names=names, decimal=',')
df
# Out:
#                                                    url  \
# 0    https://literama.sk/sk/knihy/478401/fit-krabic...
# 1    https://literama.sk/sk/knihy/511749/svou-videt...
# 2    https://literama.sk/sk/knihy/494727/vyvysene-z...
# 3    https://literama.sk/sk/knihy/511332/basne-velk...
# 4    https://literama.sk/sk/knihy/508866/makrame-an...
# ..                                                 ...
# 155  https://literama.sk/sk/knihy/476789/vsadte-na-...
# 156  https://literama.sk/sk/knihy/503852/motorky-20...
# 157  https://literama.sk/sk/knihy/512081/prva-pomoc...
# 158  https://literama.sk/sk/knihy/510230/bile-preda...
# 159  https://literama.sk/sk/knihy/503851/tipy-na-vy...
#
#                                  book name   price  \
# 0             Fit krabičky Ládi Hrušky III  14,28€
# 1                Svou vidět bledou mrtvolu  10,33€
# 2           Vyvýšené záhony Krok za krokem  15,73€
# 3                       Básně Velká Morava  27,00€
# 4                           Makramé Andělé   7,16€
# ..                                     ...     ...
# 155          Vsaďte na rostlinné bílkoviny  21,42€
# 156         Motorky 2025 - stolní kalendář   3,39€
# 157              Prvá pomoc pre vaše dieťa  19,29€
# 158            Bílé předání & Černé zbytky  20,72€
# 159  Tipy na výlety 2025 - stolní kalendář   2,82€
#
#                         category language              author  \
# 0          Životný štýl, zdravie      CZE         Láďa Hruška
# 1                         Poézia      CZE                 NaN
# 2              Hobby a voľný čas      CZE       Anja Kleinová
# 3                         Poézia      CZE          Pavel Petr
# 4    Náučná a odborná literatúra      CZE                 NaN
# ..                           ...      ...                 ...
# 155        Životný štýl, zdravie      CZE  Robin Robertsonová
# 156              Doplnkový tovar      CZE                 NaN
# 157  Náučná a odborná literatúra      SVK       Larissa Meier
# 158                       Poézia      CZE          Guy Viarre
# 159              Doplnkový tovar      CZE                 NaN
#
#             publisher           isbn                         binding  \
# 0              Esence  9788024294179  Neviazaná, bez prebalu, lesklá
# 1              Dybbuk  9788076901025      Tvrdá, bez prebalu, lesklá
# 2              Esence  9788024296197  Neviazaná, bez prebalu, lesklá
# 3        Větrné mlýny  9788074435270      Tvrdá, bez prebalu, lesklá
# 4           Bookmedia  9788076392854  Neviazaná, bez prebalu, lesklá
# ..                ...            ...                             ...
# 155        Alpha book  9788088428169  Neviazaná, bez prebalu, lesklá
# 156             HELMA  8596641003309            Špirálová, hrebeňová
# 157  Grada Publishing  9788080908300  Neviazaná, bez prebalu, lesklá
# 158               Fra  9788075212313  Neviazaná, bez prebalu, lesklá
# 159             HELMA  8596641002487            Špirálová, hrebeňová
#
#     date published  num. pages     dimensions  weight        status discount
# 0          2023/11       144.0  155×208×14 mm    0.24  U dodávateľa      13%
# 1          2024/10       180.0      90×140 mm    0.16  U dodávateľa       6%
# 2          2024/06       176.0        170×240    0.49  U dodávateľa      13%
# 3          2024/09       388.0     148×210 mm    0.74  U dodávateľa      18%
# 4          2024/10         NaN   175×225×5 mm    0.20  U dodávateľa      18%
# ..             ...         ...            ...     ...           ...      ...
# 155        2023/07       192.0     190×230 mm    0.60  U dodávateľa      13%
# 156        2024/09         NaN   230×174×5 mm    0.14  U dodávateľa       3%
# 157        2024/09       304.0     135×215 mm    0.56  U dodávateľa       8%
# 158        2024/09       396.0     100×170 mm    0.26  U dodávateľa       6%
# 159        2024/09         NaN   172×172×5 mm    0.10  U dodávateľa       3%
#
# [160 rows x 15 columns]

# %%
df.dtypes
# Out:
# url                object
# book name          object
# price              object
# category           object
# language           object
# author             object
# publisher          object
# isbn                int64
# binding            object
# date published     object
# num. pages        float64
# dimensions         object
# weight            float64
# status             object
# discount           object
# dtype: object

# %%
df.describe()
# Out:
#                isbn  num. pages      weight
# count  1.600000e+02  149.000000  152.000000
# mean   9.646381e+12  210.322148    0.485921
# std    3.868729e+11  114.654373    0.381996
# min    8.594186e+12   32.000000    0.090000
# 25%    9.788027e+12  144.000000    0.237500
# 50%    9.788075e+12  192.000000    0.380000
# 75%    9.788077e+12  247.000000    0.600000
# max    9.788097e+12  760.000000    2.210000

# %%
df.describe(include = [object])
# Out:
#                                                       url  \
# count                                                 160
# unique                                                160
# top     https://literama.sk/sk/knihy/478401/fit-krabic...
# freq                                                    1
#
#                            book name   price           category language  \
# count                            160     160                160      160
# unique                           160     119                  6        3
# top     Fit krabičky Ládi Hrušky III  12,12€  Hobby a voľný čas      CZE
# freq                               1       7                 40      117
#
#           author       publisher                         binding  \
# count        129             160                             155
# unique       122              73                              11
# top     kolektiv  PRESCOGROUP SK  Neviazaná, bez prebalu, lesklá
# freq           5              12                              54
#
#        date published     dimensions        status discount
# count             160            159           160      160
# unique             17            118             3       15
# top           2024/09  216×135×18 mm  U dodávateľa      13%
# freq               56              5           158       70

# %%
df['price'] = df['price'].apply(lambda x:  x.replace(',', '.').replace('€', '')).astype(float)

df
# Out:
#                                                    url  \
# 0    https://literama.sk/sk/knihy/478401/fit-krabic...
# 1    https://literama.sk/sk/knihy/511749/svou-videt...
# 2    https://literama.sk/sk/knihy/494727/vyvysene-z...
# 3    https://literama.sk/sk/knihy/511332/basne-velk...
# 4    https://literama.sk/sk/knihy/508866/makrame-an...
# ..                                                 ...
# 155  https://literama.sk/sk/knihy/476789/vsadte-na-...
# 156  https://literama.sk/sk/knihy/503852/motorky-20...
# 157  https://literama.sk/sk/knihy/512081/prva-pomoc...
# 158  https://literama.sk/sk/knihy/510230/bile-preda...
# 159  https://literama.sk/sk/knihy/503851/tipy-na-vy...
#
#                                  book name  price  \
# 0             Fit krabičky Ládi Hrušky III  14.28
# 1                Svou vidět bledou mrtvolu  10.33
# 2           Vyvýšené záhony Krok za krokem  15.73
# 3                       Básně Velká Morava  27.00
# 4                           Makramé Andělé   7.16
# ..                                     ...    ...
# 155          Vsaďte na rostlinné bílkoviny  21.42
# 156         Motorky 2025 - stolní kalendář   3.39
# 157              Prvá pomoc pre vaše dieťa  19.29
# 158            Bílé předání & Černé zbytky  20.72
# 159  Tipy na výlety 2025 - stolní kalendář   2.82
#
#                         category language              author  \
# 0          Životný štýl, zdravie      CZE         Láďa Hruška
# 1                         Poézia      CZE                 NaN
# 2              Hobby a voľný čas      CZE       Anja Kleinová
# 3                         Poézia      CZE          Pavel Petr
# 4    Náučná a odborná literatúra      CZE                 NaN
# ..                           ...      ...                 ...
# 155        Životný štýl, zdravie      CZE  Robin Robertsonová
# 156              Doplnkový tovar      CZE                 NaN
# 157  Náučná a odborná literatúra      SVK       Larissa Meier
# 158                       Poézia      CZE          Guy Viarre
# 159              Doplnkový tovar      CZE                 NaN
#
#             publisher           isbn                         binding  \
# 0              Esence  9788024294179  Neviazaná, bez prebalu, lesklá
# 1              Dybbuk  9788076901025      Tvrdá, bez prebalu, lesklá
# 2              Esence  9788024296197  Neviazaná, bez prebalu, lesklá
# 3        Větrné mlýny  9788074435270      Tvrdá, bez prebalu, lesklá
# 4           Bookmedia  9788076392854  Neviazaná, bez prebalu, lesklá
# ..                ...            ...                             ...
# 155        Alpha book  9788088428169  Neviazaná, bez prebalu, lesklá
# 156             HELMA  8596641003309            Špirálová, hrebeňová
# 157  Grada Publishing  9788080908300  Neviazaná, bez prebalu, lesklá
# 158               Fra  9788075212313  Neviazaná, bez prebalu, lesklá
# 159             HELMA  8596641002487            Špirálová, hrebeňová
#
#     date published  num. pages     dimensions  weight        status discount
# 0          2023/11       144.0  155×208×14 mm    0.24  U dodávateľa      13%
# 1          2024/10       180.0      90×140 mm    0.16  U dodávateľa       6%
# 2          2024/06       176.0        170×240    0.49  U dodávateľa      13%
# 3          2024/09       388.0     148×210 mm    0.74  U dodávateľa      18%
# 4          2024/10         NaN   175×225×5 mm    0.20  U dodávateľa      18%
# ..             ...         ...            ...     ...           ...      ...
# 155        2023/07       192.0     190×230 mm    0.60  U dodávateľa      13%
# 156        2024/09         NaN   230×174×5 mm    0.14  U dodávateľa       3%
# 157        2024/09       304.0     135×215 mm    0.56  U dodávateľa       8%
# 158        2024/09       396.0     100×170 mm    0.26  U dodávateľa       6%
# 159        2024/09         NaN   172×172×5 mm    0.10  U dodávateľa       3%
#
# [160 rows x 15 columns]

# %%
df = df.drop(columns=['url'])
df
# Out:
#                                  book name  price  \
# 0             Fit krabičky Ládi Hrušky III  14.28
# 1                Svou vidět bledou mrtvolu  10.33
# 2           Vyvýšené záhony Krok za krokem  15.73
# 3                       Básně Velká Morava  27.00
# 4                           Makramé Andělé   7.16
# ..                                     ...    ...
# 155          Vsaďte na rostlinné bílkoviny  21.42
# 156         Motorky 2025 - stolní kalendář   3.39
# 157              Prvá pomoc pre vaše dieťa  19.29
# 158            Bílé předání & Černé zbytky  20.72
# 159  Tipy na výlety 2025 - stolní kalendář   2.82
#
#                         category language              author  \
# 0          Životný štýl, zdravie      CZE         Láďa Hruška
# 1                         Poézia      CZE                 NaN
# 2              Hobby a voľný čas      CZE       Anja Kleinová
# 3                         Poézia      CZE          Pavel Petr
# 4    Náučná a odborná literatúra      CZE                 NaN
# ..                           ...      ...                 ...
# 155        Životný štýl, zdravie      CZE  Robin Robertsonová
# 156              Doplnkový tovar      CZE                 NaN
# 157  Náučná a odborná literatúra      SVK       Larissa Meier
# 158                       Poézia      CZE          Guy Viarre
# 159              Doplnkový tovar      CZE                 NaN
#
#             publisher           isbn                         binding  \
# 0              Esence  9788024294179  Neviazaná, bez prebalu, lesklá
# 1              Dybbuk  9788076901025      Tvrdá, bez prebalu, lesklá
# 2              Esence  9788024296197  Neviazaná, bez prebalu, lesklá
# 3        Větrné mlýny  9788074435270      Tvrdá, bez prebalu, lesklá
# 4           Bookmedia  9788076392854  Neviazaná, bez prebalu, lesklá
# ..                ...            ...                             ...
# 155        Alpha book  9788088428169  Neviazaná, bez prebalu, lesklá
# 156             HELMA  8596641003309            Špirálová, hrebeňová
# 157  Grada Publishing  9788080908300  Neviazaná, bez prebalu, lesklá
# 158               Fra  9788075212313  Neviazaná, bez prebalu, lesklá
# 159             HELMA  8596641002487            Špirálová, hrebeňová
#
#     date published  num. pages     dimensions  weight        status discount
# 0          2023/11       144.0  155×208×14 mm    0.24  U dodávateľa      13%
# 1          2024/10       180.0      90×140 mm    0.16  U dodávateľa       6%
# 2          2024/06       176.0        170×240    0.49  U dodávateľa      13%
# 3          2024/09       388.0     148×210 mm    0.74  U dodávateľa      18%
# 4          2024/10         NaN   175×225×5 mm    0.20  U dodávateľa      18%
# ..             ...         ...            ...     ...           ...      ...
# 155        2023/07       192.0     190×230 mm    0.60  U dodávateľa      13%
# 156        2024/09         NaN   230×174×5 mm    0.14  U dodávateľa       3%
# 157        2024/09       304.0     135×215 mm    0.56  U dodávateľa       8%
# 158        2024/09       396.0     100×170 mm    0.26  U dodávateľa       6%
# 159        2024/09         NaN   172×172×5 mm    0.10  U dodávateľa       3%
#
# [160 rows x 14 columns]

# %%
df['date published'] = pd.to_datetime(df['date published'], errors='coerce')
df['year'] = df['date published'].dt.year
df['month'] = df['date published'].dt.month
df
# Out:
# /tmp/ipykernel_4786/2532983629.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date published'] = pd.to_datetime(df['date published'], errors='coerce')
#                                  book name  price  \
# 0             Fit krabičky Ládi Hrušky III  14.28
# 1                Svou vidět bledou mrtvolu  10.33
# 2           Vyvýšené záhony Krok za krokem  15.73
# 3                       Básně Velká Morava  27.00
# 4                           Makramé Andělé   7.16
# ..                                     ...    ...
# 155          Vsaďte na rostlinné bílkoviny  21.42
# 156         Motorky 2025 - stolní kalendář   3.39
# 157              Prvá pomoc pre vaše dieťa  19.29
# 158            Bílé předání & Černé zbytky  20.72
# 159  Tipy na výlety 2025 - stolní kalendář   2.82
#
#                         category language              author  \
# 0          Životný štýl, zdravie      CZE         Láďa Hruška
# 1                         Poézia      CZE                 NaN
# 2              Hobby a voľný čas      CZE       Anja Kleinová
# 3                         Poézia      CZE          Pavel Petr
# 4    Náučná a odborná literatúra      CZE                 NaN
# ..                           ...      ...                 ...
# 155        Životný štýl, zdravie      CZE  Robin Robertsonová
# 156              Doplnkový tovar      CZE                 NaN
# 157  Náučná a odborná literatúra      SVK       Larissa Meier
# 158                       Poézia      CZE          Guy Viarre
# 159              Doplnkový tovar      CZE                 NaN
#
#             publisher           isbn                         binding  \
# 0              Esence  9788024294179  Neviazaná, bez prebalu, lesklá
# 1              Dybbuk  9788076901025      Tvrdá, bez prebalu, lesklá
# 2              Esence  9788024296197  Neviazaná, bez prebalu, lesklá
# 3        Větrné mlýny  9788074435270      Tvrdá, bez prebalu, lesklá
# 4           Bookmedia  9788076392854  Neviazaná, bez prebalu, lesklá
# ..                ...            ...                             ...
# 155        Alpha book  9788088428169  Neviazaná, bez prebalu, lesklá
# 156             HELMA  8596641003309            Špirálová, hrebeňová
# 157  Grada Publishing  9788080908300  Neviazaná, bez prebalu, lesklá
# 158               Fra  9788075212313  Neviazaná, bez prebalu, lesklá
# 159             HELMA  8596641002487            Špirálová, hrebeňová
#
#     date published  num. pages     dimensions  weight        status discount  \
# 0       2023-11-01       144.0  155×208×14 mm    0.24  U dodávateľa      13%
# 1       2024-10-01       180.0      90×140 mm    0.16  U dodávateľa       6%
# 2       2024-06-01       176.0        170×240    0.49  U dodávateľa      13%
# 3       2024-09-01       388.0     148×210 mm    0.74  U dodávateľa      18%
# 4       2024-10-01         NaN   175×225×5 mm    0.20  U dodávateľa      18%
# ..             ...         ...            ...     ...           ...      ...
# 155     2023-07-01       192.0     190×230 mm    0.60  U dodávateľa      13%
# 156     2024-09-01         NaN   230×174×5 mm    0.14  U dodávateľa       3%
# 157     2024-09-01       304.0     135×215 mm    0.56  U dodávateľa       8%
# 158     2024-09-01       396.0     100×170 mm    0.26  U dodávateľa       6%
# 159     2024-09-01         NaN   172×172×5 mm    0.10  U dodávateľa       3%
#
#        year  month
# 0    2023.0   11.0
# 1    2024.0   10.0
# 2    2024.0    6.0
# 3    2024.0    9.0
# 4    2024.0   10.0
# ..      ...    ...
# 155  2023.0    7.0
# 156  2024.0    9.0
# 157  2024.0    9.0
# 158  2024.0    9.0
# 159  2024.0    9.0
#
# [160 rows x 16 columns]

# %%
df['discount'] = df['discount'].apply(lambda x:  x.replace('%', '')).astype(int)
df
# Out:
#                                  book name  price  \
# 0             Fit krabičky Ládi Hrušky III  14.28
# 1                Svou vidět bledou mrtvolu  10.33
# 2           Vyvýšené záhony Krok za krokem  15.73
# 3                       Básně Velká Morava  27.00
# 4                           Makramé Andělé   7.16
# ..                                     ...    ...
# 155          Vsaďte na rostlinné bílkoviny  21.42
# 156         Motorky 2025 - stolní kalendář   3.39
# 157              Prvá pomoc pre vaše dieťa  19.29
# 158            Bílé předání & Černé zbytky  20.72
# 159  Tipy na výlety 2025 - stolní kalendář   2.82
#
#                         category language              author  \
# 0          Životný štýl, zdravie      CZE         Láďa Hruška
# 1                         Poézia      CZE                 NaN
# 2              Hobby a voľný čas      CZE       Anja Kleinová
# 3                         Poézia      CZE          Pavel Petr
# 4    Náučná a odborná literatúra      CZE                 NaN
# ..                           ...      ...                 ...
# 155        Životný štýl, zdravie      CZE  Robin Robertsonová
# 156              Doplnkový tovar      CZE                 NaN
# 157  Náučná a odborná literatúra      SVK       Larissa Meier
# 158                       Poézia      CZE          Guy Viarre
# 159              Doplnkový tovar      CZE                 NaN
#
#             publisher           isbn                         binding  \
# 0              Esence  9788024294179  Neviazaná, bez prebalu, lesklá
# 1              Dybbuk  9788076901025      Tvrdá, bez prebalu, lesklá
# 2              Esence  9788024296197  Neviazaná, bez prebalu, lesklá
# 3        Větrné mlýny  9788074435270      Tvrdá, bez prebalu, lesklá
# 4           Bookmedia  9788076392854  Neviazaná, bez prebalu, lesklá
# ..                ...            ...                             ...
# 155        Alpha book  9788088428169  Neviazaná, bez prebalu, lesklá
# 156             HELMA  8596641003309            Špirálová, hrebeňová
# 157  Grada Publishing  9788080908300  Neviazaná, bez prebalu, lesklá
# 158               Fra  9788075212313  Neviazaná, bez prebalu, lesklá
# 159             HELMA  8596641002487            Špirálová, hrebeňová
#
#     date published  num. pages     dimensions  weight        status  discount  \
# 0       2023-11-01       144.0  155×208×14 mm    0.24  U dodávateľa        13
# 1       2024-10-01       180.0      90×140 mm    0.16  U dodávateľa         6
# 2       2024-06-01       176.0        170×240    0.49  U dodávateľa        13
# 3       2024-09-01       388.0     148×210 mm    0.74  U dodávateľa        18
# 4       2024-10-01         NaN   175×225×5 mm    0.20  U dodávateľa        18
# ..             ...         ...            ...     ...           ...       ...
# 155     2023-07-01       192.0     190×230 mm    0.60  U dodávateľa        13
# 156     2024-09-01         NaN   230×174×5 mm    0.14  U dodávateľa         3
# 157     2024-09-01       304.0     135×215 mm    0.56  U dodávateľa         8
# 158     2024-09-01       396.0     100×170 mm    0.26  U dodávateľa         6
# 159     2024-09-01         NaN   172×172×5 mm    0.10  U dodávateľa         3
#
#        year  month
# 0    2023.0   11.0
# 1    2024.0   10.0
# 2    2024.0    6.0
# 3    2024.0    9.0
# 4    2024.0   10.0
# ..      ...    ...
# 155  2023.0    7.0
# 156  2024.0    9.0
# 157  2024.0    9.0
# 158  2024.0    9.0
# 159  2024.0    9.0
#
# [160 rows x 16 columns]
